# %% [markdown]
# ![](http://upl.stack.com/wp-content/uploads/2013/02/ACT-and-SAT-629x421.jpg)

# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# ## SAT - Moulding the Future of America
# >_“Education is the most powerful weapon which you can use to change the world”_ – Nelson Mandela
#
# In the wake of a competitive standardized test market, young americans now have a plethora of tests to choose from. While we are seeing high participation rates across America, there are still areas with relatively lower rates which could be explained by the following:
# * Compulsory requirement of another standardized test
# * Taking the path of less resistance: participating in an "easier" standardized test to score better.
# * University and scholarship evaluation criteria based on other tests
#
# We will analyze data trends to help us in identifying effective areas of focus, to better our SAT participation rates.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#import csv files
sat_file = "C://Users//chris//Desktop//GA//projects//project_1//data//sat_2017.csv"
act_file = "C://Users//chris//Desktop//GA//projects//project_1//data//act_2017.csv"
sat_2017 = pd.read_csv(sat_file)
act_2017 = pd.read_csv(act_file)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#display first few 10 rows of sat 2017 dataframe
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#display first few 10 rows of sat 2017 dataframe
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
#view the info summary of sat 2017
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# **Answer:**
#
# * We see that dataframe index column is unfriendly for us. Perhaps we can use the state column as index to manipulate data better.
# * Analyzing the first 10 rows of the data, we can see that based on the columns, both test have different test criterions. SAT has 2 components of testing, while ACT has 4 components.
# * SAT has 51 rows of states while ACT has 52. The difference is the one at national level figures which is included for ACT.
# * From the data provided, SAT measures total mean scores for each subject. ACT mesures the composite(average) for each mean subjects

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# **Answer**
# * Data looks complete at first glance as there is no null values.
# * States column does not look like they are repeated as well, except for the mentioned national figure which we may remove as we are unable to obtain the national figure for SAT.
# * Composite values are datatype as objects in ACT datset, when the first 10 rows of values look like floats. Will find out the cause of this

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)
# - [SAT Scoring](https://blog.collegevine.com/how-the-new-sat-is-scored/)
# - [ACT Scoring](https://blog.prepscholar.com/how-is-the-act-scored)
# - [ACT 2017 Scores by State](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf)

# %% [markdown]
# **Answer**
#
# **SAT**
# Math, Evidence-Based Reading and Writing: Min=200, Max=800
# Overall test: Min=400, Max=1600
#
# **ACT**
# English, Math, Reading, Science(scaled score): Min=1, Max=36
# Overall test: Min=1, Max=36
#
# Based on the summary statistics of both dataframes, the minimum for both the **SAT, Math** and **ACT, Science** columns have relatively much lower mean scores as compared to their column families.
#
# As per below **Math** score of **52** and **Science** score of **2.3** for **Maryland** may be incorrect.
#
# Upon re-checking the source, **Math** should be **524** and **Science** should be **23.2**

# %%
#find the outlier values for sat
sat_2017[(sat_2017["Math"] < 200)]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
#find the outlier values for sat(we use the 25% quartile as a reference)
act_2017[(act_2017["Science"] < 20)]
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 1          Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2           Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3          Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4         Arkansas          100%     18.9  19.0     19.7     19.5      19.4
# 10         Florida           73%     19.0  19.4     21.0     19.4      19.8
# 12          Hawaii           90%     17.8  19.2     19.2     19.3      19.0
# 19       Louisiana          100%     19.4  18.8     19.8     19.6      19.5
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1
# ...

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#replace sat Math score for Maryland
sat_2017.loc[(sat_2017["State"] == "Maryland"), "Math"] = 524

#replace sat Science score for Maryland
act_2017.loc[(act_2017["State"] == "Maryland"), "Science"] = 23.2

print(sat_2017.loc[(sat_2017["State"] == "Maryland")])
print(act_2017.loc[(act_2017["State"] == "Maryland")])
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# **Answer**
# * For both datatframes, the data type of 'participation' and 'composite' are objects. Hence we are unable to sort them accordingly.
#
# * Upon investigating the composite column, we find that **Wyoming** state has an additional "x" at then end of its value. We will need to clean this

# %%
#find out why composite column in ACT 2017 is a object datatype
act_2017.loc[:, ["State", "Composite"]]
# Out:
#                    State Composite
# 0               National      21.0
# 1                Alabama      19.2
# 2                 Alaska      19.8
# 3                Arizona      19.7
# 4               Arkansas      19.4
# 5             California      22.8
# 6               Colorado      20.8
# 7            Connecticut      25.2
# 8               Delaware      24.1
# 9   District of Columbia      24.2
# 10               Florida      19.8
# 11               Georgia      21.4
# 12                Hawaii      19.0
# 13                 Idaho      22.3
# 14              Illinois      21.4
# 15               Indiana      22.6
# 16                  Iowa      21.9
# 17                Kansas      21.7
# 18              Kentucky      20.0
# 19             Louisiana      19.5
# 20                 Maine      24.3
# 21              Maryland      23.6
# 22         Massachusetts      25.4
# 23              Michigan      24.1
# 24             Minnesota      21.5
# 25           Mississippi      18.6
# ...

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#define remove percent function to remove the % in participation values
def remove_percent(i):
    return i.strip('%')

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#change the value composite value for wyoming 
act_2017.loc[act_2017['State'] == 'Wyoming', 'Composite'] = 20.2

print(act_2017.loc[act_2017['State'] == 'Wyoming', 'Composite'])
# Out:
# 51    20.2
# Name: Composite, dtype: object

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#remove pecent from sat 2017 dataset
sat_2017["Participation"] = sat_2017["Participation"].apply(remove_percent)

#change sat 2017 participation column to floats
sat_2017["Participation"] = sat_2017["Participation"].astype('float64')

#remove pecent from act 2017 dataset
act_2017["Participation"] = act_2017["Participation"].apply(remove_percent)

#change act 2017 participation column to floats
act_2017["Participation"] = act_2017["Participation"].astype('float64')

#change the act 2017 participation column to floats
act_2017["Composite"] = act_2017["Composite"].astype('float64')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
#renaming sat 2017 columns
sat_2017.rename(columns = {'State': 'state',
                           'Participation': 'participation_sat_2017',
                           'Evidence-Based Reading and Writing': 'erw_sat_2017',
                           'Math': 'math_sat_2017',
                           'Total': 'total_sat_2017'}, inplace = True
                )

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
#renaming act 2017 columns
act_2017.rename(columns = {'State': 'state',
                           'Participation': 'participation_act_2017',
                           'English': 'english_act_2017',
                           'Math': 'math_act_2017',
                           'Reading': 'reading_act_2017',
                           'Science': 'science_act_2017',
                           'Composite': 'composite_act_2017'}, inplace = True
               )

# %%
sat_2017.head()
# Out:
#         state  participation_sat_2017  erw_sat_2017  math_sat_2017  \
# 0     Alabama                     5.0           593            572
# 1      Alaska                    38.0           547            533
# 2     Arizona                    30.0           563            553
# 3    Arkansas                     3.0           614            594
# 4  California                    53.0           531            524
#
#    total_sat_2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %%
act_2017.head()
# Out:
#       state  participation_act_2017  english_act_2017  math_act_2017  \
# 0  National                    60.0              20.3           20.7
# 1   Alabama                   100.0              18.9           18.4
# 2    Alaska                    65.0              18.7           19.8
# 3   Arizona                    62.0              18.6           19.8
# 4  Arkansas                   100.0              18.9           19.0
#
#    reading_act_2017  science_act_2017  composite_act_2017
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   participation_sat_2017  51 non-null     float64
#  2   erw_sat_2017            51 non-null     int64
#  3   math_sat_2017           51 non-null     int64
#  4   total_sat_2017          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   52 non-null     object
#  1   participation_act_2017  52 non-null     float64
#  2   english_act_2017        52 non-null     float64
#  3   math_act_2017           52 non-null     float64
#  4   reading_act_2017        52 non-null     float64
#  5   science_act_2017        52 non-null     float64
#  6   composite_act_2017      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |<p style='text-align: left;'> Feature </p> |<p style='text-align: left;'> Type </p> |<p style='text-align: left;'> Dataset </p> | <p style='text-align: left;'> Description </p> |
# |---|---|---|---|
# |<p style='text-align: left;'> state </p> | Object  | SAT 2017 |<p style='text-align: left;'> US states where participants are from </p> |
# |<p style='text-align: left;'> participation_sat_2017 </p>| Float  | SAT 2017 |<p style='text-align: left;'> Percentage of total students that participated in 2017 </p>  |
# |<p style='text-align: left;'> erw_sat_2017 </p> | Float  | SAT 2017 |<p style='text-align: left;'> Mean score for Evidence-Based Reading and Writing in 2017 </p> |
# |<p style='text-align: left;'> math_sat_2017 </p> | Float  | SAT 2017  |<p style='text-align: left;'> Mean score for Math in 2017 </p> |
# |<p style='text-align: left;'> total_sat_2017 </p> | Float  | SAT 2017  |<p style='text-align: left;'> Total mean score(Evidence-Based Reading and Writing & Math) in 2017 </p> |
# |<p style='text-align: left;'> participation_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Percentage of total students that participated in 2017 </p> |
# |<p style='text-align: left;'> english_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for English in 2017 </p> |
# |<p style='text-align: left;'> math_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Math in 2017 </p> |
# |<p style='text-align: left;'> reading_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Reading in 2017 </p> |
# |<p style='text-align: left;'> science_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Science in 2017 </p> |
# |<p style='text-align: left;'> composite_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean of total mean scores of (English, Math, Reading, Science) in 2017 </p> |

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#drop the national values in act 2017
act_2017.drop([0])
# Out:
#                    state  participation_act_2017  english_act_2017  \
# 1                Alabama                   100.0              18.9
# 2                 Alaska                    65.0              18.7
# 3                Arizona                    62.0              18.6
# 4               Arkansas                   100.0              18.9
# 5             California                    31.0              22.5
# 6               Colorado                   100.0              20.1
# 7            Connecticut                    31.0              25.5
# 8               Delaware                    18.0              24.1
# 9   District of Columbia                    32.0              24.4
# 10               Florida                    73.0              19.0
# 11               Georgia                    55.0              21.0
# 12                Hawaii                    90.0              17.8
# 13                 Idaho                    38.0              21.9
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#merge sat and act 2017 together
merged_2017 = pd.merge(sat_2017, act_2017, on="state")

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#save clean merged data to folder
merged_2017.to_csv("C://Users//chris//Desktop//GA//projects//project_1//data//merged_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#import 2018 sat and actcsv files to notebook
sat_2018_file = "C://Users//chris//Desktop//GA//projects//project_1//data//sat_2018.csv"
act_2018_file = "C://Users//chris//Desktop//GA//projects//project_1//data//act_2018.csv"
sat_2018 = pd.read_csv(sat_2018_file)
act_2018 = pd.read_csv(act_2018_file)

# %% [markdown]
# ### Inspect data for 2018 datasets

# %%
#inspect first 10 rows of 2018 datasets
display(sat_2018.head(10))
display(act_2018.head(10))

#inspect summary info of 2018 datasets
display(sat_2018.info())
display(act_2018.info())

#inspect summary statistics of the 2018 datasets
display(sat_2018.describe())
display(act_2018.describe())
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %% [markdown]
# ### First impression of 2018 datasets
#
# **SAT 2018:**
# * Shape: Similar to sat 2017, has 5 columns and 51 non null entries. Columns names are all same as sat 2017.
# * Summary info: data types are similar as sat2017. Participant column is an object
# * Summary statistics: min and max values are within the range of the SAT test as explained previously.
# * **To clean:**
# * We will need inpect further to see if there are any duplicated values under 'state' column
# * Participation column needs to be changed to float
# * Rename columns
#
# **ACT 2018:**
# * Shape: 52 row values but only 3 columns.
# * Summary info: Participant column is an object which requires cleaning.
# * Summary statistics: min and max values of composite column are within the range of the act test as explained previously.
# * **To clean:**
# * We will need to fill in rest of the test subject columns of the dataset to that similar of act 2017
# * We will need inpect further to see if there are any duplicated values under 'state' column
# * Participation column needs to be changed to float
# * Rename columns
# * Remove national figure

# %% [markdown]
# ### Cleaning SAT 2018 Dataset

# %% [markdown]
# #### Finding duplicates

# %%
#finding any duplicate values in state column
display(sat_2018[sat_2018.duplicated(["State"])])
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %% [markdown]
# #### Change participation column data type to float

# %%
#changing data type for participation column
#remove pecent from participation column
sat_2018["Participation"] = sat_2018["Participation"].apply(remove_percent)

#change participation column to floats
sat_2018["Participation"] = sat_2018["Participation"].astype('float64')

display(sat_2018.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# None

# %% [markdown]
# #### Rename columns

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
#renaming sat 2018 columns
sat_2018.rename(columns = {'State': 'state',
                           'Participation': 'participation_sat_2018',
                           'Evidence-Based Reading and Writing': 'erw_sat_2018',
                           'Math': 'math_sat_2018',
                           'Total': 'total_sat_2018'}, inplace = True
                )

display(sat_2018.head())
# Out:
#         state  participation_sat_2018  erw_sat_2018  math_sat_2018  \
# 0     Alabama                     6.0           595            571
# 1      Alaska                    43.0           562            544
# 2     Arizona                    29.0           577            572
# 3    Arkansas                     5.0           592            576
# 4  California                    60.0           540            536
#
#    total_sat_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %% [markdown]
# ### Cleaning ACT 2018 Dataset

# %% [markdown]
# #### Import updated ACT 2018

# %% [markdown]
# To fill in the rest of the column data test subjects, we will load the updated act 2018 csv file

# %%
#read updated act 2018 data
act_2018_updated_file = "C://Users//chris//Desktop//GA//projects//project_1//data//act_2018_updated.csv"
act_2018_updated = pd.read_csv(act_2018_updated_file)

# %%
#inspect first few rows of act 2018 updated
display(act_2018_updated.head())
display(act_2018_updated.info())
display(act_2018_updated.describe())
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %% [markdown]
# **First impression of ACT 2018 dataset:**
#
# Shape: 51 row values and 7 columns. This is similar to act 2017 dataset with national figures already removed.
# Summary info: Datatypes are as they should be. Will change Participation column to float for consistency.
# Summary statistics: min and max values of composite column are within the range of the act test as explained previously.
#
# **To clean:**
# * We will need inpect further to see if there are any duplicated values under 'state' column
# * Participation column needs to be changed to float
# * Rename columns

# %%
#change datatype from integer to float
act_2018_updated['Percentage of Students Tested'] = act_2018_updated['Percentage of Students Tested'].astype(float)

act_2018_updated.dtypes
# Out:
# State                             object
# Percentage of Students Tested    float64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
#rename columns 
act_2018_updated.rename(columns = {'State': 'state',
                                   'Percentage of Students Tested': 'participation_act_2018',
                                   'Average Composite Score': 'composite_act_2018',
                                   'Average English Score': 'english_act_2018',
                                   'Average Math Score': 'math_act_2018',
                                   'Average Reading Score': 'reading_act_2018',
                                   'Average Science Score': 'science_act_2018',
                                  }, inplace=True
                       )

act_2018_updated.head()
# Out:
#         state  participation_act_2018  composite_act_2018  english_act_2018  \
# 0     Alabama                   100.0                19.1              18.9
# 1      Alaska                    33.0                20.8              19.8
# 2     Arizona                    66.0                19.2              18.2
# 3    Arkansas                   100.0                19.4              19.1
# 4  California                    27.0                22.7              22.5
#
#    math_act_2018  reading_act_2018  science_act_2018
# 0           18.3              19.6              19.0
# 1           20.6              21.6              20.7
# 2           19.4              19.5              19.2
# 3           18.9              19.7              19.4
# 4           22.5              23.0              22.1

# %%
#check for any duplicates state column
display(act_2018_updated[act_2018_updated.duplicated(["state"])])
# Out:
# Empty DataFrame
# Columns: [state, participation_act_2018, composite_act_2018, english_act_2018, math_act_2018, reading_act_2018, science_act_2018]
# Index: []

# %%
act_2018_updated["state"].value_counts()
# Out:
# Virginia                1
# Wyoming                 1
# Alaska                  1
# Mississippi             1
# North Carolina          1
# Maine                   1
# Iowa                    1
# Nevada                  1
# Tennessee               1
# Delaware                1
# Maryland                1
# New Hampshire           1
# Missouri                1
# North Dakota            1
# Wisconsin               1
# Arizona                 1
# New York                1
# Minnesota               1
# Alabama                 1
# Oregon                  1
# Arkansas                1
# Colorado                1
# Idaho                   1
# Massachusetts           1
# Georgia                 1
# Kansas                  1
# South Carolina          1
# Rhode Island            1
# Florida                 1
# Indiana                 1
# District of Columbia    1
# Connecticut             1
# Utah                    1
# Montana                 1
# Illinois                1
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
display(merged_2017.head())
display(sat_2018.head())
display(act_2018_updated.head())
# Out:
#         state  participation_sat_2017  erw_sat_2017  math_sat_2017  \
# 0     Alabama                     5.0           593            572
# 1      Alaska                    38.0           547            533
# 2     Arizona                    30.0           563            553
# 3    Arkansas                     3.0           614            594
# 4  California                    53.0           531            524
#
#    total_sat_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    reading_act_2017  science_act_2017  composite_act_2017
# ...

# %%
#merging sat 2018 dataframe to merged 2017 on state
merged_partial = pd.merge(merged_2017, sat_2018, on='state')

#merging sat 2018 dataframe to merged 2017 on state
merged_final = pd.merge(merged_partial, act_2018_updated, on='state')

# %%
#view first few rows of final dataframe
merged_final.head()
# Out:
#         state  participation_sat_2017  erw_sat_2017  math_sat_2017  \
# 0     Alabama                     5.0           593            572
# 1      Alaska                    38.0           547            533
# 2     Arizona                    30.0           563            553
# 3    Arkansas                     3.0           614            594
# 4  California                    53.0           531            524
#
#    total_sat_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    reading_act_2017  science_act_2017  ...  participation_sat_2018  \
# ...

# %%
merged_final.dtypes
# Out:
# state                      object
# participation_sat_2017    float64
# erw_sat_2017                int64
# math_sat_2017               int64
# total_sat_2017              int64
# participation_act_2017    float64
# english_act_2017          float64
# math_act_2017             float64
# reading_act_2017          float64
# science_act_2017          float64
# composite_act_2017        float64
# participation_sat_2018    float64
# erw_sat_2018                int64
# math_sat_2018               int64
# total_sat_2018              int64
# participation_act_2018    float64
# composite_act_2018        float64
# english_act_2018          float64
# math_act_2018             float64
# reading_act_2018          float64
# science_act_2018          float64
# dtype: object

# %%
#standardize all integers to floats
merged_final['erw_sat_2017'] = merged_final['erw_sat_2017'].astype(float)
merged_final['math_sat_2017'] = merged_final['math_sat_2017'].astype(float)
merged_final['total_sat_2017'] = merged_final['total_sat_2017'].astype(float)
merged_final['erw_sat_2018'] = merged_final['erw_sat_2018'].astype(float)
merged_final['math_sat_2018'] = merged_final['math_sat_2018'].astype(float)
merged_final['total_sat_2018'] = merged_final['total_sat_2018'].astype(float)

# %% [markdown]
# #### Data Dictionary for 2017 and 2018

# %% [markdown]
# |<p style='text-align: left;'> Feature </p> |<p style='text-align: left;'> Type </p> |<p style='text-align: left;'> Dataset </p> | <p style='text-align: left;'> Description </p> |
# |---|---|---|---|
# |<p style='text-align: left;'> state </p> | Object  | SAT 2017 |<p style='text-align: left;'> US states where participants are from </p> |
# |<p style='text-align: left;'> participation_sat_2017 </p>| Float  | SAT 2017 |<p style='text-align: left;'> Percentage of total students that participated in 2017 </p>  |
# |<p style='text-align: left;'> erw_sat_2017 </p> | Float  | SAT 2017 |<p style='text-align: left;'> Mean score for Evidence-Based Reading and Writing in 2017 </p> |
# |<p style='text-align: left;'> math_sat_2017 </p> | Float  | SAT 2017  |<p style='text-align: left;'> Mean score for Math in 2017 </p> |
# |<p style='text-align: left;'> total_sat_2017 </p> | Float  | SAT 2017  |<p style='text-align: left;'> Total mean score(Evidence-Based Reading and Writing & Math) in 2017 </p> |
# |<p style='text-align: left;'> participation_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Percentage of total students that participated in 2017 </p> |
# |<p style='text-align: left;'> english_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for English in 2017 </p> |
# |<p style='text-align: left;'> math_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Math in 2017 </p> |
# |<p style='text-align: left;'> reading_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Reading in 2017 </p> |
# |<p style='text-align: left;'> science_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean score for Science in 2017 </p> |
# |<p style='text-align: left;'> composite_act_2017 </p> | Float  | ACT 2017  |<p style='text-align: left;'> Mean of total mean scores of (English, Math, Reading, Science) in 2017 </p> |
# |<p style='text-align: left;'> participation_sat_2018 </p>| Float  | SAT 2018 |<p style='text-align: left;'> Percentage of total students that participated in 2018 </p>  |
# |<p style='text-align: left;'> erw_sat_2018 </p> | Float  | SAT 2018 |<p style='text-align: left;'> Mean score for Evidence-Based Reading and Writing in 2018 </p> |
# |<p style='text-align: left;'> math_sat_2018 </p> | Float  | SAT 2018  |<p style='text-align: left;'> Mean score for Math in 2018 </p> |
# |<p style='text-align: left;'> total_sat_2018 </p> | Float  | SAT 2018  |<p style='text-align: left;'> Total mean score(Evidence-Based Reading and Writing & Math) in 2018 </p> |
# |<p style='text-align: left;'> participation_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Percentage of total students that participated in 2018 </p> |
# |<p style='text-align: left;'> english_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Mean score for English in 2018 </p> |
# |<p style='text-align: left;'> math_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Mean score for Math in 2018 </p> |
# |<p style='text-align: left;'> reading_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Mean score for Reading in 2018 </p> |
# |<p style='text-align: left;'> science_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Mean score for Science in 2018 </p> |
# |<p style='text-align: left;'> composite_act_2018 </p> | Float  | ACT 2018  |<p style='text-align: left;'> Mean of total mean scores of (English, Math, Reading, Science) in 2018 </p> |

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#summary statistic for merged dataframe
merged_final.describe()
# Out:
#        participation_sat_2017  erw_sat_2017  math_sat_2017  total_sat_2017  \
# count               51.000000     51.000000      51.000000       51.000000
# mean                39.803922    569.117647     556.882353     1126.098039
# std                 35.276632     45.666901      47.121395       92.494812
# min                  2.000000    482.000000     468.000000      950.000000
# 25%                  4.000000    533.500000     523.500000     1055.500000
# 50%                 38.000000    559.000000     548.000000     1107.000000
# 75%                 66.000000    613.000000     599.000000     1212.000000
# max                100.000000    644.000000     651.000000     1295.000000
#
#        participation_act_2017  english_act_2017  math_act_2017  \
# count               51.000000         51.000000      51.000000
# mean                65.254902         20.931373      21.182353
# std                 32.140842          2.353677       1.981989
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def variance(data_set):
    n = len(data_set) #number of values in data
    mean = sum(data_set)/ n #mean of list of data
    return sum((x-mean) ** 2 for x in data_set) / n
    
def std_dev(data_set):
    var = variance(data_set)
    stddev = var ** 0.5
    return stddev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
merged_final.dtypes
# Out:
# state                      object
# participation_sat_2017    float64
# erw_sat_2017              float64
# math_sat_2017             float64
# total_sat_2017            float64
# participation_act_2017    float64
# english_act_2017          float64
# math_act_2017             float64
# reading_act_2017          float64
# science_act_2017          float64
# composite_act_2017        float64
# participation_sat_2018    float64
# erw_sat_2018              float64
# math_sat_2018             float64
# total_sat_2018            float64
# participation_act_2018    float64
# composite_act_2018        float64
# english_act_2018          float64
# math_act_2018             float64
# reading_act_2018          float64
# science_act_2018          float64
# dtype: object

# %%
#Code:
sd = {column:std_dev(merged_final[column]) for column in merged_final.columns if merged_final[column].dtype == 'float64'}

# %%
sd
# Out:
# {'participation_sat_2017': 34.92907076664508,
#  'erw_sat_2017': 45.21697020437866,
#  'math_sat_2017': 46.65713364485503,
#  'total_sat_2017': 91.58351056778743,
#  'participation_act_2017': 31.824175751231806,
#  'english_act_2017': 2.3304876369363363,
#  'math_act_2017': 1.9624620273436781,
#  'reading_act_2017': 2.0469029314842646,
#  'science_act_2017': 1.7222161451443676,
#  'composite_act_2017': 2.000786081581989,
#  'participation_sat_2018': 36.946619223539415,
#  'erw_sat_2018': 47.03460978357609,
#  'math_sat_2018': 47.30194550378352,
#  'total_sat_2018': 93.22742384464433,
#  'participation_act_2018': 33.745194881997506,
#  'composite_act_2018': 2.0855261815801147,
#  'english_act_2018': 2.4222536143202795,
#  'math_act_2018': 2.015707255555717,
#  'reading_act_2018': 2.145891884510421,
#  'science_act_2018': 1.8516885484833543}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
np.std(merged_final)
# Out:
# participation_sat_2017    34.929071
# erw_sat_2017              45.216970
# math_sat_2017             46.657134
# total_sat_2017            91.583511
# participation_act_2017    31.824176
# english_act_2017           2.330488
# math_act_2017              1.962462
# reading_act_2017           2.046903
# science_act_2017           1.722216
# composite_act_2017         2.000786
# participation_sat_2018    36.946619
# erw_sat_2018              47.034610
# math_sat_2018             47.301946
# total_sat_2018            93.227424
# participation_act_2018    33.745195
# composite_act_2018         2.085526
# english_act_2018           2.422254
# math_act_2018              2.015707
# reading_act_2018           2.145892
# science_act_2018           1.851689
# dtype: float64

# %% [markdown]
# **Answer**
#
# * No. My manual calculations do not match up to the output from pandas describe, whereas it matches up to outputs from numpy describe.
# * Numpy uses population n to calculate standard deviaton whereas pandas uses unbiased n-1 denominator as sample. Hence the difference.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# #### Set index to state column

# %%
merged_final.set_index('state', inplace=True)

# %% [markdown]
# #### SAT 2017 Participation Rates by State

# %%
#highest SAT 2017 participation rates
display(merged_final.participation_sat_2017.sort_values(ascending=False).head())
# Out:
# state
# Connecticut             100.0
# Delaware                100.0
# District of Columbia    100.0
# Michigan                100.0
# New Hampshire            96.0
# Name: participation_sat_2017, dtype: float64

# %% [markdown]
# States with **highest** participation rates for **SAT in 2017** are:
# * Connecticut
# * Delaware
# * District of Columbia
# * Michigan

# %%
#lowest SAT 2017 participation rates
display(merged_final.participation_sat_2017.sort_values(ascending=True).head())
# Out:
# state
# North Dakota    2.0
# Mississippi     2.0
# Iowa            2.0
# Missouri        3.0
# Utah            3.0
# Name: participation_sat_2017, dtype: float64

# %% [markdown]
# Sates with **lowest** participation rates for **SAT in 2017** are:
# * North Dakota
# * Mississippi
# * Iowa

# %% [markdown]
# #### SAT 2018 Participation Rates by State

# %%
#highest SAT 2018 participation rates
display(merged_final.participation_sat_2018.sort_values(ascending=False).head(6))
# Out:
# state
# Idaho          100.0
# Michigan       100.0
# Delaware       100.0
# Connecticut    100.0
# Colorado       100.0
# Illinois        99.0
# Name: participation_sat_2018, dtype: float64

# %% [markdown]
# States with **highest** participation rates for **SAT in 2018** are:
# * Idaho
# * Michigan
# * Delaware
# * Connecticut
# * Colorado

# %%
#lowest SAT 2018 participation rates
display(merged_final.participation_sat_2018.sort_values(ascending=True).head())
# Out:
# state
# North Dakota    2.0
# Wyoming         3.0
# South Dakota    3.0
# Nebraska        3.0
# Wisconsin       3.0
# Name: participation_sat_2018, dtype: float64

# %% [markdown]
# State with **lowest** participation rates for **SAT in 2018** is:
# * North Dakota

# %% [markdown]
# #### ACT 2017 Participation Rates by State

# %%
#highest ACT 2017 participation rates
display(merged_final.participation_act_2017.sort_values(ascending=False).head())
# Out:
# state
# Wyoming     100.0
# Oklahoma    100.0
# Arkansas    100.0
# Colorado    100.0
# Kentucky    100.0
# Name: participation_act_2017, dtype: float64

# %% [markdown]
# States with **highest** participation rates for **ACT in 2017** are:
# * Wyoming
# * Oklahoma
# * Arkansas
# * Colorado
# * Kentucky

# %%
#lowest ACT 2017 participation rates
display(merged_final.participation_act_2017.sort_values(ascending=True).head())
# Out:
# state
# Maine             8.0
# New Hampshire    18.0
# Delaware         18.0
# Rhode Island     21.0
# Pennsylvania     23.0
# Name: participation_act_2017, dtype: float64

# %% [markdown]
# State with **lowest** participation rates for **ACT in 2017** is:
# * Maine

# %% [markdown]
# #### ACT 2018 Participation Rates by State

# %%
#highest ACT 2018 participation rates
display(merged_final.participation_act_2018.sort_values(ascending=False).head())
# Out:
# state
# Wyoming      100.0
# Oklahoma     100.0
# Arkansas     100.0
# Kentucky     100.0
# Louisiana    100.0
# Name: participation_act_2018, dtype: float64

# %% [markdown]
# States with **highest** participation rates for **ACT in 2018** are:
# * Wyoming
# * Oklahoma
# * Arkansas
# * Kentucky
# * Louisiana

# %%
#lowest ACT 2018 participation rates
display(merged_final.participation_act_2018.sort_values(ascending=True).head())
# Out:
# state
# Maine             7.0
# Rhode Island     15.0
# New Hampshire    16.0
# Delaware         17.0
# Pennsylvania     20.0
# Name: participation_act_2018, dtype: float64

# %% [markdown]
# State with **lowest** participation rates for **ACT in 2018** is:
# * Maine

# %% [markdown]
# #### SAT 2017 Total Score by State

# %%
#highest sat 2017 total score
display(merged_final.total_sat_2017.sort_values(ascending=False).head())
# Out:
# state
# Minnesota    1295.0
# Wisconsin    1291.0
# Iowa         1275.0
# Missouri     1271.0
# Kansas       1260.0
# Name: total_sat_2017, dtype: float64

# %% [markdown]
# State with **highest** total score for **SAT in 2017** is:
# * Minnesota

# %%
#lowest sat 2017 total score
display(merged_final.total_sat_2017.sort_values(ascending=True).head())
# Out:
# state
# District of Columbia     950.0
# Delaware                 996.0
# Idaho                   1005.0
# Michigan                1005.0
# Maine                   1012.0
# Name: total_sat_2017, dtype: float64

# %% [markdown]
# State with **lowest** total score for **SAT in 2017** is:
# * District of Columbia

# %% [markdown]
# #### SAT 2018 Total Score by State

# %%
#highest sat 2018 total score
display(merged_final.total_sat_2018.sort_values(ascending=False).head())
# Out:
# state
# Minnesota       1298.0
# Wisconsin       1294.0
# North Dakota    1283.0
# Iowa            1265.0
# Kansas          1265.0
# Name: total_sat_2018, dtype: float64

# %% [markdown]
# State with **highest** total score for **SAT in 2018** is:
# * Minnesota

# %%
#lowest sat 2018 total score
display(merged_final.total_sat_2018.sort_values(ascending=True).head())
# Out:
# state
# District of Columbia     977.0
# Delaware                 998.0
# West Virginia            999.0
# Idaho                   1001.0
# Utah                    1010.0
# Name: total_sat_2018, dtype: float64

# %% [markdown]
# State with **lowest** total score for **SAT in 2018** is:
# * District of Columbia

# %% [markdown]
# #### ACT 2017 Composite Score by State

# %%
#highest act 2017 composite score
display(merged_final.composite_act_2017.sort_values(ascending=False).head())
# Out:
# state
# New Hampshire           25.5
# Massachusetts           25.4
# Connecticut             25.2
# Maine                   24.3
# District of Columbia    24.2
# Name: composite_act_2017, dtype: float64

# %% [markdown]
# State with **highest** composite score for **ACT in 2017** is:
# * New Hampshire

# %%
#lowest act 2017 composite score
display(merged_final.composite_act_2017.sort_values(ascending=True).head())
# Out:
# state
# Nevada            17.8
# Mississippi       18.6
# South Carolina    18.7
# Hawaii            19.0
# North Carolina    19.1
# Name: composite_act_2017, dtype: float64

# %% [markdown]
# State with **lowest** composite score for **ACT in 2017** is:
# * Nevada

# %% [markdown]
# #### ACT 2018 Composite Score by State

# %%
#highest act 2018 comoposite score
display(merged_final.composite_act_2018.sort_values(ascending=False).head())
# Out:
# state
# Connecticut      25.6
# Massachusetts    25.5
# New Hampshire    25.1
# New York         24.5
# Michigan         24.4
# Name: composite_act_2018, dtype: float64

# %% [markdown]
# State with **highest** composite score for **ACT in 2017** is:
# * Connecticut

# %%
#lowest act 2018 composite score
display(merged_final.composite_act_2018.sort_values(ascending=True).head())
# Out:
# state
# Nevada            17.7
# South Carolina    18.3
# Mississippi       18.6
# Hawaii            18.9
# Alabama           19.1
# Name: composite_act_2018, dtype: float64

# %% [markdown]
# State with **lowest** composite score for **ACT in 2018** is:
# * Nevada

# %% [markdown]
# #### Year on Year participation rates analysis : 100% rates
# * Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
#selecting states where SAT had 100% participation rate in 2017, but not in 2018
sat_part_mask_1 = (merged_final.participation_sat_2017 == 100) & (merged_final.participation_sat_2018 != 100)
merged_final[sat_part_mask_1 ][['participation_sat_2017', 'participation_sat_2018']]
# Out:
#                       participation_sat_2017  participation_sat_2018
# state
# District of Columbia                   100.0                    92.0

# %%
#selecting states where SAT had 100% participation rate in 2018, but not in 2017
sat_part_mask_2 = (merged_final.participation_sat_2017 != 100) & (merged_final.participation_sat_2018 == 100)
merged_final[sat_part_mask_2][['participation_sat_2017', 'participation_sat_2018']]
# Out:
#           participation_sat_2017  participation_sat_2018
# state
# Colorado                    11.0                   100.0
# Idaho                       93.0                   100.0

# %%
#selecting states where ACT had 100% participation rate in 2017, but not in 2018
act_part_mask_1 = (merged_final.participation_act_2017 == 100) & (merged_final.participation_act_2018 != 100)
merged_final[act_part_mask_1][['participation_act_2017', 'participation_act_2018']]
# Out:
#            participation_act_2017  participation_act_2018
# state
# Colorado                    100.0                    30.0
# Minnesota                   100.0                    99.0

# %%
#selecting states where ACT had 100% participation rate in 2018, but not in 2017
act_part_mask_2 = (merged_final.participation_act_2017 != 100) & (merged_final.participation_act_2018 == 100)
merged_final[act_part_mask_2][['participation_act_2017', 'participation_act_2018']]
# Out:
#           participation_act_2017  participation_act_2018
# state
# Nebraska                    84.0                   100.0
# Ohio                        75.0                   100.0

# %% [markdown]
# #### Year on Year participation rates analysis: >50% rates
# * Do any states show have >50% participation on both tests either year?

# %%
#selecting states where SAT had >50% participation rate in both years
sat_part_mask_3 = (merged_final.participation_sat_2017 > 50) & (merged_final.participation_sat_2018 >50)
merged_final[sat_part_mask_3][['participation_sat_2017', 'participation_sat_2018']]
# Out:
#                       participation_sat_2017  participation_sat_2018
# state
# California                              53.0                    60.0
# Connecticut                            100.0                   100.0
# Delaware                               100.0                   100.0
# District of Columbia                   100.0                    92.0
# Florida                                 83.0                    56.0
# Georgia                                 61.0                    70.0
# Hawaii                                  55.0                    56.0
# Idaho                                   93.0                   100.0
# Indiana                                 63.0                    63.0
# Maine                                   95.0                    99.0
# Maryland                                69.0                    76.0
# Massachusetts                           76.0                    80.0
# ...

# %%
#selecting states where ACT had >50% participation rate in both years
act_part_mask_3 = (merged_final.participation_act_2017 > 50) & (merged_final.participation_act_2018 >50)
merged_final[act_part_mask_3][['participation_act_2017', 'participation_act_2018']]
# Out:
#                 participation_act_2017  participation_act_2018
# state
# Alabama                          100.0                   100.0
# Arizona                           62.0                    66.0
# Arkansas                         100.0                   100.0
# Florida                           73.0                    66.0
# Georgia                           55.0                    53.0
# Hawaii                            90.0                    89.0
# Iowa                              67.0                    68.0
# Kansas                            73.0                    71.0
# Kentucky                         100.0                   100.0
# Louisiana                        100.0                   100.0
# Minnesota                        100.0                    99.0
# Mississippi                      100.0                   100.0
# Missouri                         100.0                   100.0
# Montana                          100.0                   100.0
# ...

# %% [markdown]
# #### Summary Trend Analysis
#
# * On first glance, there is a negative correlation between participation rates of SAT and ACT. States with higher participation rates in SAT usually have lower participation rates in ACT. Conversely, states like Wyoming who have high take up rate for ACT will unlikely take up the SAT due the heavy load of doing 2 tests.
#
# **SAT**
# * There seems to be a negative correlation between participation rate and total score. It seems like even though participatnts from states like Michigan, Delaware and District of Columbia have the highest participation rates, their results seem to be one of the lowest year on year relative to the other states.
# * This can be further evidenced from those states whith >50% participation rates, generally are not among the highest scoring states.
# * Conversely, states with lower participation rates like North Dakota, Iowa and Wisconsin have higher scores that those that have higher participation rates.
# * However, this may not be a fair comparison as lower participation relates to smaller sample size, thus total mean results of participants will either only be very high or very low.
# * State of Colorado has seen the highest jump in participation rate from 11% to 100% year on year. This could be resulted from compulsory requirements by the state to use SAT test scores as college admission criteria.
# * Participation rate for District of Columbia shows a decrease of 8% which chould be result of low total scores scored trend seen year on year. Participants might be turned off by the difficulty of the test.
#
# **ACT**
# * Generally a large number of states with 100% participation due to compulsory requirements by states to take up ACT.
# * States participation trend generally stays the same as well which could probably due to the requirements.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (12,12))
sns.heatmap(merged_final.corr(), linewidths=0.5, cmap='RdBu', annot=True)
plt.title(('Correlation of 2017-2018 SAT and ACT Test Scores and Participation Rates'), fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation of 2017-2018 SAT and ACT Test Scores and Participation Rates')

# %% [markdown]
# We wish to drop the test subjects in order to analyse participation rates with total scores.
# Students will be more concerned of the total scores, that they are able to achieve in order to get successful placement into the college of their choice. Test subjects will be

# %%
merged_final.columns
# Out:
# Index(['participation_sat_2017', 'erw_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'participation_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_sat_2018', 'erw_sat_2018',
#        'math_sat_2018', 'total_sat_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018'],
#       dtype='object')

# %%
#drop unncessary columns
merged_final_2 = merged_final.drop(columns = ['erw_sat_2017', 'math_sat_2017', 'english_act_2017',
                                                 'math_act_2017', 'reading_act_2017', 'science_act_2017',
                                                 'erw_sat_2018', 'math_sat_2018', 'english_act_2018',
                                                 'math_act_2018', 'reading_act_2018', 'science_act_2018'
                                                ]

                                  )


#correlation for new df
corr = merged_final_2.corr()
#plot heat map
sns.set_style(style="white")
#create mask for upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 8))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#title
plt.title(('Correlation of 2017-2018 SAT and ACT Test Scores and Participation Rates'), fontsize=15)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, annot = True, cbar_kws={"shrink": .5})

# %% [markdown]
# #### Correlation analysis
# There is a strong negative correlation('blue') between participation rates of both test for both years. This could suggest that participants do switch between tests.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_colours):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=10, color=list_of_colours[i])# feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize=12)# Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[0], fontsize=10)# Set xlabel
        ax[i].set_ylabel(list_of_xlabels[1], fontsize=10)# Set ylabel
        ax[i].grid(True)#apply grid to plots

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
merged_final.columns
# Out:
# Index(['participation_sat_2017', 'erw_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'participation_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_sat_2018', 'erw_sat_2018',
#        'math_sat_2018', 'total_sat_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018'],
#       dtype='object')

# %% [markdown]
# ##### Participation rates for SAT & ACT

# %%
#Plot histograms for Participation rates of SAT & ACT
columns = ['participation_sat_2017','participation_act_2017', 
           'participation_sat_2018','participation_act_2018']
titles = ['2017 SAT Participation Rate by State', '2017 ACT Participation Rate by State', 
          '2018 SAT Participation Rate by State', '2018 ACT Participation Rate by State']
xlabels = ['Participation Rates(%)', 'Number of States']
colours = ['#005AB5', '#DC3220','#005AB5','#DC3220']
                   
subplot_histograms(merged_final, columns, titles, xlabels, colours)
plt.tight_layout()

# %% [markdown]
# Comparing by test for each year, we can see the trend SAT has more states with low participation rates and vice versa for ACT.
# This could be explained by several states deeming ACT as mandatory requirement. Hence have larger number of states with 100% participation.
#
# Both of them seem to be symmetrical to each other.

# %% [markdown]
# ##### Math scores for SAT & ACT

# %%
#Plot histograms for math scores for SAT & ACT
columns = ['math_sat_2017','math_act_2017', 
           'math_sat_2018','math_act_2018']
titles = ['2017 SAT Mean Math Score by State', '2017 ACT Mean Math Score by State', 
          '2018 SAT Mean Math Score by State', '2018 ACT Mean Math Score by State']
xlabels = ['Mean Score', 'Number of States']
colours = ['#005AB5', '#DC3220','#005AB5','#DC3220']
                   
subplot_histograms(merged_final, columns, titles, xlabels, colours)
plt.tight_layout()

# %% [markdown]
# The trend of scores seem to be constant year on year for both SAT and ACT test. Though there was an increase in number of states having higher math scores than SAT year on year. This could be due to the difficuly of test set, with one test being less challenging than the other.

# %% [markdown]
# ##### Reading/verbal scores for SAT & ACT
# This includes SAT's Evidence Based Reading and Writing, as well as ACT's English and Reading test subjects.

# %%
#Plot histograms for reading/verbal scores for SAT & ACT
columns = ['erw_sat_2017','erw_sat_2018','reading_act_2017','reading_act_2018','english_act_2017','english_act_2018']
titles = ['2017 SAT Mean Evidence-Based Reading & Writing Score by State', '2018 SAT Mean Evidence-Based Reading & Writing Score by State', 
          '2017 ACT Mean Reading Score by State', '2018 ACT Mean Reading Score by State', '2017 ACT Mean English Score by State', '2018 ACT Mean English Score by State']
xlabels = ['Mean Score', 'Number of States']
colours = ['#005AB5', '#005AB5','#DC3220','#DC3220','#004D40','#004D40']
                   
subplot_histograms(merged_final, columns, titles, xlabels, colours)
plt.tight_layout()

# %% [markdown]
# Similary the trend of scores seem to be constant year on year for both SAT and ACT test. However, we can see states generally score better in SAT's evidence based reading and writing as compare to reading for ACT.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# ##### Scatter plot of SAT vs. ACT mean scores for each test subject for 2017

# %%
#scatter plot of 2017 math scores of SAT and ACT
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["math_sat_2017"], merged_final["math_act_2017"],
color="blue")
ax.set_title("2017 SAT vs. ACT mean math scores", fontsize=25)
ax.set_xlabel("2017 SAT mean math scores", fontsize=20)
ax.set_ylabel("2017 ACT mean math scores", fontsize=20)
# Out:
# Text(0, 0.5, '2017 ACT mean math scores')

# %%
#scatter plot of 2017 verbal/reading scores of SAT and ACT(Reading)
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["erw_sat_2017"], merged_final["reading_act_2017"],
color="red")
ax.set_title("2017 SAT vs. ACT mean verbal/reading scores", fontsize=25)
ax.set_xlabel("2017 SAT mean erw scores", fontsize=20)
ax.set_ylabel("2017 ACT mean reading scores", fontsize=20)
# Out:
# Text(0, 0.5, '2017 ACT mean reading scores')

# %%
#scatter plot of 2017 verbal/reading scores of SAT and ACT(English)
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["erw_sat_2017"], merged_final["english_act_2017"],
color="teal")
ax.set_title("2017 SAT vs. ACT mean verbal/reading scores", fontsize=25)
ax.set_xlabel("2017 SAT mean erw scores", fontsize=20)
ax.set_ylabel("2017 ACT mean english scores", fontsize=20)
# Out:
# Text(0, 0.5, '2017 ACT mean english scores')

# %%
#scatter plot of 2017 total/composite scores of SAT and ACT
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["total_sat_2017"], merged_final["composite_act_2017"],
color="green")
ax.set_title("2017 SAT total vs. ACT composite mean scores", fontsize=25)
ax.set_xlabel("2017 SAT mean total scores", fontsize=20)
ax.set_ylabel("2017 ACT mean composite scores", fontsize=20)
# Out:
# Text(0, 0.5, '2017 ACT mean composite scores')

# %%
#Scatter plot for total scores for SAT 2017 vs. 2018
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["total_sat_2017"], merged_final["total_sat_2018"],
color="orange")
ax.set_title("2017 vs. 2018 SAT total mean scores", fontsize=25)
ax.set_xlabel("2017 SAT mean total scores", fontsize=15)
ax.set_ylabel("2018 SAT mean total scores", fontsize=15)
# Out:
# Text(0, 0.5, '2018 SAT mean total scores')

# %%
#Scatter plot for composite scores for ACT 2017 vs. 2018
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(merged_final["composite_act_2017"], merged_final["composite_act_2018"],
color="purple")
ax.set_title("2017 vs. 2018 ACT mean composite scores", fontsize=25)
ax.set_xlabel("2017 ACT mean composite scores", fontsize=20)
ax.set_ylabel("2018 ACT mean composite scores", fontsize=20)
# Out:
# Text(0, 0.5, '2018 ACT mean composite scores')

# %% [markdown]
# ##### Intrepreting scatter plots

# %% [markdown]
# Generally for test subjects between the 2 tests, while data points are quite sparse, there is some slight signs of a negative downward sloping trend. At the extreme ends of the plot, we can see that for the same subject, states that did well for a particular test, did badly for the other. These are probably states that have mandated requirements. Hence students do 1 test or the other.
#
# For total mean/composite scores, it is generally understood that scores should have a correlation close to 1 an hence can be evidenced by the positive correlation trend that we see for both SAT and ACT test.
#
# For SAT, we do notice a few states falling below the trend line. This refers to the states that fared worse in 2018 than in 2017
#
# ACT remains relatively stable as compare to SAT with 2 states falling away from the trend line with more states maintaining the scores year on year.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#set function for boxplot
def box_plotter(list_of_columns, list_of_colors, title, xlabel, ylabel):
    plt.figure(figsize=(12,8))
    participation = sns.boxplot(data=merged_final[list_of_columns])
    for i, column in enumerate(list_of_columns):
        participation.artists[i].set_facecolor(list_of_colors[i])
    plt.title(title, fontsize=28)
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)

# %%
#Participation rates in SAT and ACT for 2017 and 2018

columns = ["participation_sat_2017","participation_act_2017", 
           "participation_sat_2018","participation_act_2018"]
title = 'Participation rates for SAT and ACT'
xlabel = 'tests'
ylabel = 'participation rate'
colours = ['#005AB5', '#DC3220','#005AB5','#DC3220']

box_plotter(columns, colours, title, xlabel, ylabel)

# %% [markdown]
# * Participation rates are evidently higher for ACT as compared to SAT in both years with higher medians.
# * Participation rates for ACT have their 3rd quartiles(75th percentile) at the maximum. This means that at least 25% of the population have maximum participation rate of 100%
# * Conversely, SAT's quartile range is nearer to the minimum of 2%.
# * Comparing year on year, ACT rates seem to be maintaining at a stable rate with medians at about 70%.
# * SAT showed a slight increase in median, but still lower as compared to ACT.

# %%
#Total mean scores for SAT in 2017 and 2018
columns = ["total_sat_2017","total_sat_2018"]
title = 'Total mean scores for SAT in 2017 and 2018'
xlabel = 'year'
ylabel = 'total mean score'
colours = ['#005AB5', '#009E73']

box_plotter(columns, colours, title, xlabel, ylabel)

# %% [markdown]
# * Overall, total mean scores for SAT remained similar in both years.
# * The minimum did increase slightly to about 980 from 950 in 2017

# %%
#Composite scores for ACT in 2017 and 2018
columns = ["composite_act_2017","composite_act_2018"]
title = 'Composite scores for ACT in 2017 and 2018'
xlabel = 'year'
ylabel = 'composite score'
colours = ['#88CCEE', '#FFB000']
box_plotter(columns, colours, title, xlabel, ylabel)

# %% [markdown]
# * Overall, composite scores for SAT remained similar in both years.
# * The 25th percentile shifted slightly higher to about 20.2 in 2018.

# %%
merged_final.columns
# Out:
# Index(['participation_sat_2017', 'erw_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'participation_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_sat_2018', 'erw_sat_2018',
#        'math_sat_2018', 'total_sat_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018'],
#       dtype='object')

# %%
#Test subject scores for SAT in 2017 and 2018
columns = ["erw_sat_2017","math_sat_2017", "erw_sat_2018", "math_sat_2018"]
title = 'Mean test subject scores for SAT in 2017 and 2018'
xlabel = 'year'
ylabel = 'mean score'
colours = ['#40B0A6', '#E1BE6A', '#40B0A6', '#E1BE6A']
box_plotter(columns, colours, title, xlabel, ylabel)

# %% [markdown]
# * Overall, students did better in evidence based reading and writing than in math with higher medians and 25th percentiles.
# * Year on year, evidence based reading and writing had a slight increase in 25th percentile. However, there was a slight drop in median score.
# * Math scores were stable year on year.

# %%
#Test subject scores for ACT in 2017 and 2018
columns = ["english_act_2017","math_act_2017", "reading_act_2017", "science_act_2017",
          "english_act_2018", "math_act_2018", "reading_act_2018", "science_act_2018"]
title = 'Mean test subject scores for ACT in 2017 and 2018'
xlabel = 'test & year'
ylabel = 'mean score'
colours = ['#C36DF9', '#D81B60', '#1E88E5', '#FFC107',
          '#C36DF9', '#D81B60', '#1E88E5', '#FFC107']
box_plotter(columns, colours, title, xlabel, ylabel)

# %% [markdown]
# * Overall, reading was the best subject out of the 4 subjects with the highest median and interquartile ranges.
# * While most subjects faired similarly for the 2 years, there was a noticable drop in english results in 2018 where the median dropped to about 20.5 from the previous 20.9

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# ##### Participation Rates Summary Statistics

# %%
merged_final.columns
# Out:
# Index(['participation_sat_2017', 'erw_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'participation_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_sat_2018', 'erw_sat_2018',
#        'math_sat_2018', 'total_sat_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018'],
#       dtype='object')

# %%
merged_final[["participation_sat_2017", "participation_sat_2018", "participation_act_2017", "participation_act_2018"]].describe()
# Out:
#        participation_sat_2017  participation_sat_2018  participation_act_2017  \
# count               51.000000               51.000000               51.000000
# mean                39.803922               45.745098               65.254902
# std                 35.276632               37.314256               32.140842
# min                  2.000000                2.000000                8.000000
# 25%                  4.000000                4.500000               31.000000
# 50%                 38.000000               52.000000               69.000000
# 75%                 66.000000               77.500000              100.000000
# max                100.000000              100.000000              100.000000
#
#        participation_act_2018
# count               51.000000
# mean                61.647059
# std                 34.080976
# min                  7.000000
# 25%                 28.500000
# 50%                 66.000000
# 75%                100.000000
# ...

# %% [markdown]
# **SAT participation rate**
# * **In 2017**, the **mean** rate was about **40%** with **median** at **38%**
# * **In 2018**, the **mean** rate was about **46%** with **median** at **52%**
# * There is an overall slight increase in participation rates from 2017 to 2018 which is evidenced by the change in skweness of distribution from positive to negative from 2017 to 2018.
# * In both years, there the spread of the participation rates where the lowest rate for a state is only **2%** while the highest is **100%**.
# * This explains the high standard deviation of about **37%** in both years
#
# **ACT participation rate**
# * **In 2017**, the **mean** rate was about **65%** with **median** at **69%**
# * **In 2018**, the **mean** rate was about **61%** with **median** at **66%**
# * Despite a slight overall decline in mean participation rates, participation rates are evidently higher for ACT test than SAT.
# * Skewness of for ACT distributions have slightly negative skews due to many states mandating student to take the ACT test.
# * The spread of the participation rates are similarly wide where the lowest rate for a state is only **7%** while the highest is **100%**. Thus a standard deviation of about **34%**
#
# In summary, despite having an increase in participation rates, SAT evidently still has lower participation rates than ACT tests year on year. This could be explained by more states do mandate students to particpate in ACT over SAT test, and students unwilling to take on 2 tests. Another factor could be that colleges recognise the ACT test over SAT test for their admission criteria.

# %% [markdown]
# ##### SAT Test Components Summary Statistics

# %%
merged_final[["erw_sat_2017","erw_sat_2018","math_sat_2017","math_sat_2018","total_sat_2017","total_sat_2018"]].describe()
# Out:
#        erw_sat_2017  erw_sat_2018  math_sat_2017  math_sat_2018  \
# count     51.000000     51.000000      51.000000      51.000000
# mean     569.117647    563.686275     556.882353     556.235294
# std       45.666901     47.502627      47.121395      47.772623
# min      482.000000    480.000000     468.000000     480.000000
# 25%      533.500000    534.500000     523.500000     522.500000
# 50%      559.000000    552.000000     548.000000     544.000000
# 75%      613.000000    610.500000     599.000000     593.500000
# max      644.000000    643.000000     651.000000     655.000000
#
#        total_sat_2017  total_sat_2018
# count       51.000000       51.000000
# mean      1126.098039     1120.019608
# std         92.494812       94.155083
# min        950.000000      977.000000
# 25%       1055.500000     1057.500000
# 50%       1107.000000     1098.000000
# 75%       1212.000000     1204.000000
# max       1295.000000     1298.000000

# %% [markdown]
# **For evidence based reading and writing**
# * **In 2017**, the **mean** score was about **569** with **median** at **559**
# * **In 2018**, the **mean** score was about **563** with **median** at **552**
# * Both distributions have slightly positive skews.
# * The range of min:480, max: 644 resulted **standard deviation of around 46%** for both distributions.
#
# **For math**
# * **In 2017**, the **mean** score was about **557** with **median** at **548**
# * **In 2018**, the **mean** score was about **556** with **median** at **544**
# * Both distributions have slightly positive skews.
# * The range of min:468, max: 655 resulted **standard deviation of around 47%** for both distributions.
#
# **For total scores**
# * **In 2017**, the **mean** score was about **1126** with **median** at **1107**
# * **In 2018**, the **mean** score was about **1120** with **median** at **1098**
# * Both distributions have slightly positive skews.
# * The range of min:950, max: 1298 resulted **standard deviation of around 94%** for both distributions.

# %% [markdown]
# ##### ACT Test Components Summary Statistics

# %%
merged_final[['english_act_2017','english_act_2018','math_act_2017','math_act_2018',
              'reading_act_2017','reading_act_2018','science_act_2017','science_act_2018',
              'composite_act_2017','composite_act_2018']].describe()
# Out:
#        english_act_2017  english_act_2018  math_act_2017  math_act_2018  \
# count         51.000000         51.000000      51.000000      51.000000
# mean          20.931373         20.988235      21.182353      21.125490
# std            2.353677          2.446356       1.981989       2.035765
# min           16.300000         16.600000      18.000000      17.800000
# 25%           19.000000         19.100000      19.400000      19.400000
# 50%           20.700000         20.200000      20.900000      20.700000
# 75%           23.300000         23.700000      23.100000      23.150000
# max           25.500000         26.000000      25.300000      25.200000
#
#        reading_act_2017  reading_act_2018  science_act_2017  science_act_2018  \
# count         51.000000         51.000000         51.000000         51.000000
# mean          22.013725         22.015686         21.450980         21.345098
# std            2.067271          2.167245          1.739353          1.870114
# ...

# %% [markdown]
# **For english**
# * **In 2017**, the **mean** score was about **21** with **median** at **20**
# * **In 2018**, the **mean** score was about **21** with **median** at **20**
# * Both distributions have slightly positive skews.
# * The range of min:16, max: 26 resulted **standard deviation of around 2.35%** for both distributions.
#
# **For math**
# * **In 2017**, the **mean** score was about **21** with **median** at **20**
# * **In 2018**, the **mean** score was about **21** with **median** at **20**
# * Both distributions are have slightly positive skews.
# * The range of min:17, max:25 resulted **standard deviation of around 2%** for both distributions.
#
# **For reading**
# * **In 2017**, the **mean** score was about **22** with **median** at **21**
# * **In 2018**, the **mean** score was about **22** with **median** at **21**
# * Both distributions are have slightly positive skews.
# * The range of min:18, max:26 resulted **standard deviation of around 2%** for both distributions.
#
# **For science**
# * **In 2017**, the **mean** score was about **22** with **median** at **21**
# * **In 2018**, the **mean** score was about **22** with **median** at **21**
# * Both distributions are have slightly positive skews.
# * The range of min:18, max:24 resulted **standard deviation of around 1.8%** for both distributions.
#
# **For composite scores**
# * **In 2017**, the **mean** score was about **21.5** with **median** at **21.4**
# * **In 2018**, the **mean** score was about **21.4** with **median** at **21.3**
# * Both distributions are have slightly positive skews.
# * The range of min:17.7, max: 25.6 resulted **standard deviation of around 2.1%** for both distributions.

# %% [markdown]
# In summary for test subjects of both tests, ACT test are closer to central tendency and are close to normal distribution.
# * Mean and Median
# The means for all test subjects of ACT are closer to their medians as compared to SAT.
# * Standard deviation
# ACT have much lower standard deviations for their test subjects scores at around 2% while SAT have generally high standard deviations for their scores.
#
# Thus, students could have chosen ACT test over SAT test because of this with the understanding of the test being able to maintain the same standard of difficulty year on year.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# **Answer**
# No. While participation rate ACT tests looks closer to normal distribution than SAT, participation rates are generally not normally distributed due to states mandating their students to take a specific test.
# With students not willing to take on 2 tests in the same year, ranges of participation rates will be large with minimum and maximum close to 0% and 100% for those states that impose requirements.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# **Answer:**
# As mentioned previously, even though ACT test distribution for rates and test subjects are closer to normal distribution and low standard deviation, they are still not normally distributed. They are either skewed slightly to the right or left, hence drawing estimates from these data will result in non accurate estimates of scores and rates.
# This is further evidenced from the histogram plotted for rates and subjects for both tests, with some even having multi modal distributions, particularly for rates.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# **Answer:**
# No.
# * The issue here is the population
# * There could be an overlap in populations(ie there are students who take both ACT and SAT tests). Hence it would be difficult to account for these group of students which will lead to inaccuracies.
# * We do not know the population size of each state as well. Only the percentage was given.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# **Answer:**
# No.
# * The issue here is the statistic
# * Both SAT and ACT are graded in a different manner as explained above. Hence they both have different scales of measurement.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
#selecting states where SAT had 100% participation rate in 2017, but not in 2018
mask_a = (merged_final.participation_sat_2018 < 10) & (merged_final.total_sat_2018 > 1200)
merged_final[mask_a ][['participation_sat_2017', 'participation_sat_2018', 'total_sat_2017', 'total_sat_2018',]]
# Out:
#               participation_sat_2017  participation_sat_2018  total_sat_2017  \
# state
# Iowa                             2.0                     3.0          1275.0
# Kansas                           4.0                     4.0          1260.0
# Kentucky                         4.0                     4.0          1247.0
# Louisiana                        4.0                     4.0          1198.0
# Minnesota                        3.0                     4.0          1295.0
# Mississippi                      2.0                     3.0          1242.0
# Missouri                         3.0                     4.0          1271.0
# Nebraska                         3.0                     3.0          1253.0
# North Dakota                     2.0                     2.0          1256.0
# South Dakota                     3.0                     3.0          1216.0
# Tennessee                        5.0                     6.0          1228.0
# ...

# %% [markdown]
# ##### 1. Colorado
# (https://www.denverpost.com/2017/03/06/colorado-juniors-sat-college-exam/)
# * As  per our analysis, Colorado had a large increase in SAT participation rate year on year where by it jumped from 11% to 100%
# * Conversely this also resulted in the large drecrease in ACT participation rate year on year where by it declined from 100% to 30%
# * This is due to Colorado lawmaker's decision to switch from mandated ACT to SAT test citing the reason that it suits it aligns closer to Colorado Academic Standards.
# * Furthermore, SAT provides better test preparation for its students.
#
# ##### 2. Illinois
# (https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# * Similar to Colorado, Illinois had the relatively big increase in SAT participation rate year on year where by it jumped from 9% to 99%
# * Conversely this also resulted in the biggest drecrease in ACT participation rate year on year where by it declined from 93% to 43%
# * Resons cited was that SAT provides more information than ever before about a student's readiness, and directly links to resources that offer distinct opportunities to students, such as free, personalized online test practice through Khan Academy
# * Fee waivers are also provided for students
#
# ##### 3. Iowa
# (https://wcfcourier.com/news/breaking_news/iowas-sat-scores-rank-high-nationally-participation-low/article_f59bcf7f-df03-53a7-bb6e-55a0caac633f.html)
# * Based on our data, Iowa has one of the lowest overall participation rate year on year for SAT but scored one of the highest total scoring states for both years.
# * Officials said the few students who took the test tend to be strong academically, often taking the SAT to get into large universities or to qualify for national scholarships.
# * This could also be due to a smaller pool of sample size as compared to states with 100% participation rates.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Recomend that we target **Iowa** as the state to improve SAT participation rate
# * The most effective way is to increase participation is to make SAT mandatory.
# * Iowa has currently no mandated SAT or ACT test requirements. Hence they will be easier to approach.
# * Work with states to market SAT's strength in test preparation to provide assurance to states that they are able to achieve good scores.
#
#
# Additional data that we might have to better make a better assessement would be:
# * College requirements for SAT and ACT for each state
# * Percentage of successful admissions into college using either SAT or ACT
# * Income of households that participants are from that choose SAT or ACT
